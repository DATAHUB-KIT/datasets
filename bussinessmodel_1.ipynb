# %%
import pandas as pd
df=pd.read_csv("/content/diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#statistical and EDA
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df['Glucose'])
# Out:
# (array([  5.,   0.,   4.,  33., 159., 220., 168.,  98.,  58.,  50.]),
#  array([  0. ,  19.9,  39.8,  59.7,  79.6,  99.5, 119.4, 139.3, 159.2,
#         179.1, 199. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df['Glucose'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a3072c0b830>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a3072c09e50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a3072c07710>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a3072c08680>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a3072c092e0>],
#  'means': []}

# %%
df['Glucose'].describe()
# Out:
# count    795.000000
# mean     121.245283
# std       32.067686
# min        0.000000
# 25%       99.000000
# 50%      117.000000
# 75%      141.000000
# max      199.000000
# Name: Glucose, dtype: float64

# %%
print(np.min(df['Glucose']))
print(np.max(df['Glucose']))
print(np.mean(df['Glucose']))
print(np.median(df['Glucose']))
print(stats.kurtosis(df['Glucose']))
print(stats.skew(df['Glucose']))
print(np.std(df['Glucose']))
print(np.var(df['Glucose'])
# Out:
# 0
# 199

# %%
#implement machine learning

# %%
#Data cleaning and Transformation
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#replace null values with zero
df.fillna(0)
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#split X,y (input,output features)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
X=df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]
y=df['Outcome']

# %%
#split Train,Test data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=10)

# %%
data=df

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
for col in X.columns:
    X[col] = encoder.fit_transform(X[col])
X.head()
# Out:
# /tmp/ipython-input-3383388860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = encoder.fit_transform(X[col])
# /tmp/ipython-input-3383388860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = encoder.fit_transform(X[col])
# /tmp/ipython-input-3383388860.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=10)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn.linear_model import LinearRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)
lr.predict([[]])

# %%
X.head(1)
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0       86             22             28        0  123
#
#    DiabetesPedigreeFunction  Age
# 0                       350   29

# %%
knn.predict([[86,22,28,0,123,350,	29]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %% [markdown]
# Unit 1 & 2 – Applying AI/ML to Business Business problem formulation → ML pipeline → model outcomes Unit 3 – Choosing the Right Tool Hardware, GPUs, cloud, open vs proprietary, performance trade-offs Unit 4 – Data Privacy & Ethics Privacy laws, fairness, transparency, humanitarian principles integrated per case

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
X=df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age',]]

# %%
y=df['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=10)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
X.head(1)
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50

# %%
knn.predict([[147,70,34,0,34.5,0.98,45]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
#single core processor
import time
start=time.time()
knn = KNeighborsClassifier(n_neighbors=5, n_jobs=1)
knn.fit(X_train, y_train)
cpu_time = time.time() - start
print(f"Time: {cpu_time:.4f}s")
# Out:
# Time: 0.0031s

# %%
#Two core processor
import time
start=time.time()
knn = KNeighborsClassifier(n_neighbors=5, n_jobs=2)
knn.fit(X_train, y_train)
cpu_time = time.time() - start
print(f"Time: {cpu_time:.4f}s")
# Out:
# Time: 0.0032s

# %%
#data privacy practices
#synthetic data

# %%
X_train.columns
# Out:
# Index(['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
X_train.describe()
# Out:
#           Glucose  BloodPressure  SkinThickness     Insulin         BMI  \
# count  477.000000     477.000000     477.000000  477.000000  477.000000
# mean    60.981132      21.331237      15.668763   43.607966  110.297694
# std     31.273288       8.663851      13.318786   53.612124   58.990808
# min      0.000000       0.000000       0.000000    0.000000    0.000000
# 25%     38.000000      16.000000       0.000000    0.000000   69.000000
# 50%     56.000000      22.000000      16.000000   11.000000  107.000000
# 75%     83.000000      27.000000      26.000000   82.000000  152.000000
# max    134.000000      45.000000      50.000000  185.000000  247.000000
#
#        DiabetesPedigreeFunction         Age
# count                477.000000  477.000000
# mean                 229.945493   12.316562
# std                  142.593008   11.375117
# min                    1.000000    0.000000
# 25%                  118.000000    3.000000
# 50%                  204.000000    9.000000
# ...

# %%
import numpy as np, pandas as pd
np.random.seed(42)
synthetic = pd.DataFrame({
    "Glucose": np.random.randint(0, 134, 1000),
    "Bloodpressure": np.random.normal(0, 45, 1000),
    "SkinThickness": np.random.normal(0, 50, 1000),
    "Insulin": np.random.choice([0,185], 1000, p=[0.7,0.3]),
    "BMI": np.random.normal(30, 5, 1000),
    "DiabetesPedigreeFunction": np.random.normal(0.3, 0.1, 1000),
    "Age": np.random.randint(20, 70, 1000),
})
synthetic.head()
# Out:
#    Glucose  Bloodpressure  SkinThickness  Insulin        BMI  \
# 0      102     -10.125266      -3.161173        0  21.459075
# 1       92      54.341648     -76.076383      185  34.090864
# 2       14      10.371925       9.079342        0  35.884281
# 3      106      19.453893      85.458062        0  32.422602
# 4       71      24.345084     -56.021133        0  22.327599
#
#    DiabetesPedigreeFunction  Age
# 0                  0.166495   69
# 1                  0.190983   44
# 2                  0.364733   54
# 3                  0.404456   51
# 4                  0.261028   68
